# %%
  aug=True
  images, labels, x_train, x_test, y_train, y_test, input_shape = init_data(75,75,aug)

  for m in models_to_run:
    if m<0:
      aug=False
      m*=-1
    else:
      aug=True
    
    if m==1: 
      my_network(0)
      print(3*'\n')
    elif m==2: 
      my_network_deeper(0)
      print(3*'\n')
    elif m==100:
      VGG16_net(1)
      print(3*'\n')
    elif m==200:
      VGG19_net(1)
      print(3*'\n')
    elif m==300:
      ResNet50V2_net(2)
      print(3*'\n')
    elif m==400:
      InceptionV3_net(3)
      print(3*'\n')
# Out:
# Caricamento immagini dal dataset...
#
# Model Name: MyNetwork
# Data Augmentation: True
# Iperparametri: [epochs: 15, loss: categorical_crossentropy, batch_size: 256, validation_split: 0.3]
# Ottimizzatore: {'class_name': 'Adam', 'config': {'name': 'Adam', 'learning_rate': 0.001, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}}
# Parametri addestrabili: 980779
# Parametri non addestrabili: 0.0
# Parametri totali: 980779.0
#
# Epoch 1/15
# 1716/1716 [==============================] - 207s 120ms/step - loss: 1.3243 - f1_score: 0.4847 - accuracy: 0.6063 - precision: 0.8513 - recall: 0.4614 - val_loss: 0.6445 - val_f1_score: 0.7368 - val_accuracy: 0.7959 - val_precision: 0.8947 - val_recall: 0.7175
# Epoch 2/15
# ...
